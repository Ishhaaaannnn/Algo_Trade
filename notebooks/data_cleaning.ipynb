# %%
import pandas as pd

# %%
raw_path = r'D:\Projects\Algo_trade\cache\NIFTY_50_2025-10-13_2025-11-12_5m.csv'
raw_df = pd.read_csv(raw_path)
raw_df.head()
# Out:
#                        Price       Adj Close           Close             High  \
# 0                     Ticker           ^NSEI           ^NSEI            ^NSEI
# 1                   Datetime             NaN             NaN              NaN
# 2  2025-10-13 03:45:00+00:00  25213.80078125  25213.80078125  25239.849609375
# 3  2025-10-13 03:50:00+00:00         25216.0         25216.0   25223.94921875
# 4  2025-10-13 03:55:00+00:00  25196.44921875  25196.44921875   25216.94921875
#
#               Low             Open Volume
# 0           ^NSEI            ^NSEI  ^NSEI
# 1             NaN              NaN    NaN
# 2  25176.80078125   25182.80078125      0
# 3  25200.94921875  25213.849609375      0
# 4  25187.30078125  25216.599609375      0

# %%
raw_df = raw_df.rename(columns={'Price':'DateTime'})
raw_df.head()
# Out:
#                     DateTime       Adj Close           Close             High  \
# 0                     Ticker           ^NSEI           ^NSEI            ^NSEI
# 1                   Datetime             NaN             NaN              NaN
# 2  2025-10-13 03:45:00+00:00  25213.80078125  25213.80078125  25239.849609375
# 3  2025-10-13 03:50:00+00:00         25216.0         25216.0   25223.94921875
# 4  2025-10-13 03:55:00+00:00  25196.44921875  25196.44921875   25216.94921875
#
#               Low             Open Volume
# 0           ^NSEI            ^NSEI  ^NSEI
# 1             NaN              NaN    NaN
# 2  25176.80078125   25182.80078125      0
# 3  25200.94921875  25213.849609375      0
# 4  25187.30078125  25216.599609375      0

# %%
raw_df = raw_df.drop(index=[0,1], columns='Volume').reset_index(drop=True)

raw_df.head()
# Out:
#                     DateTime        Adj Close            Close  \
# 0  2025-10-13 03:45:00+00:00   25213.80078125   25213.80078125
# 1  2025-10-13 03:50:00+00:00          25216.0          25216.0
# 2  2025-10-13 03:55:00+00:00   25196.44921875   25196.44921875
# 3  2025-10-13 04:00:00+00:00  25163.349609375  25163.349609375
# 4  2025-10-13 04:05:00+00:00  25201.900390625  25201.900390625
#
#               High              Low             Open
# 0  25239.849609375   25176.80078125   25182.80078125
# 1   25223.94921875   25200.94921875  25213.849609375
# 2   25216.94921875   25187.30078125  25216.599609375
# 3   25197.05078125  25154.849609375   25196.19921875
# 4   25203.80078125          25153.5   25163.19921875

# %%
df = raw_df.drop(columns='Adj Close')
df.head()
# Out:
#                     DateTime            Close             High  \
# 0  2025-10-13 03:45:00+00:00   25213.80078125  25239.849609375
# 1  2025-10-13 03:50:00+00:00          25216.0   25223.94921875
# 2  2025-10-13 03:55:00+00:00   25196.44921875   25216.94921875
# 3  2025-10-13 04:00:00+00:00  25163.349609375   25197.05078125
# 4  2025-10-13 04:05:00+00:00  25201.900390625   25203.80078125
#
#                Low             Open
# 0   25176.80078125   25182.80078125
# 1   25200.94921875  25213.849609375
# 2   25187.30078125  25216.599609375
# 3  25154.849609375   25196.19921875
# 4          25153.5   25163.19921875

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  1440 non-null   object
#  1   Close     1440 non-null   object
#  2   High      1440 non-null   object
#  3   Low       1440 non-null   object
#  4   Open      1440 non-null   object
# dtypes: object(5)
# memory usage: 56.4+ KB

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])
df.head()
# Out:
#                    DateTime            Close             High  \
# 0 2025-10-13 03:45:00+00:00   25213.80078125  25239.849609375
# 1 2025-10-13 03:50:00+00:00          25216.0   25223.94921875
# 2 2025-10-13 03:55:00+00:00   25196.44921875   25216.94921875
# 3 2025-10-13 04:00:00+00:00  25163.349609375   25197.05078125
# 4 2025-10-13 04:05:00+00:00  25201.900390625   25203.80078125
#
#                Low             Open
# 0   25176.80078125   25182.80078125
# 1   25200.94921875  25213.849609375
# 2   25187.30078125  25216.599609375
# 3  25154.849609375   25196.19921875
# 4          25153.5   25163.19921875
